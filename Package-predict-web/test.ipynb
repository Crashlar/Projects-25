# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("placement_extended.csv")

# %%
data.isna().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (41776, 2)

# %%
df = data.copy()

# %%
df.head()
# Out:
#    cgpa  package
# 0  7.47     3.60
# 1  6.86     2.92
# 2  7.61     3.09
# 3  8.46     3.53
# 4  6.77     2.81

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
X = df.iloc[:,0:1]
y = df.iloc[: , -1]

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train ,y_test = train_test_split(X , y , test_size= 0.2 , random_state= 2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train , lr.predict(X_train) , color = 'red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa')
# Out:
# Text(0, 0.5, 'Package(in lpa')

# %%
print(lr.predict(X_test.iloc[0].values.reshape(1 , 1)))
print(lr.predict(X_test.iloc[1].values.reshape(1 , 1)))
print(lr.predict(X_test.iloc[2].values.reshape(1 , 1)))
# Out:
# [2.63373237]
# [3.07174707]
# [3.45856525]
# c:\Users\Crashlar\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\Users\Crashlar\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\Users\Crashlar\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
